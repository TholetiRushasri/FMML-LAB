# %% [markdown]
# <a href="https://colab.research.google.com/github/TholetiRushasri/FMML-LAB/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-31 06:43:44--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M  69.2MB/s    in 1.0s
#
# 2024-03-31 06:43:45 (69.2 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 11778  1701.00757v1  Signed networks allow to model positive and ne...  stat
# 7847   1803.08089v1  In learning-to-learn the goal is to infer a le...  stat
# 23600   0909.5460v2  The problem of reconstruction of digital image...    cs
# 21550   1006.3316v1  A challenging problem in estimating high-dimen...  stat
# 30537  1712.04927v1  Text spotting is an interesting research probl...    cs
# ...             ...                                                ...   ...
# 21790  1505.04780v2  We present a unified framework for low-rank ma...  stat
# 22674  1704.01871v1  Cluster analysis of very high dimensional data...  stat
# 22342  1602.06349v1  We propose the segmented iHMM (siHMM), a hiera...  stat
# 22929  1711.01847v1  A powerful approach for understanding neural p...  stat
# 38555   1012.1184v1  As a powerful statistical image modeling techn...    cs
#
#                                                    title  year  \
# 11778  Clustering Signed Networks with the Geometric ...  2017
# 7847   Incremental Learning-to-Learn with Statistical...  2018
# 23600  Iterative Shrinkage Approach to Restoration of...  2009
# 21550  Stability Approach to Regularization Selection...  2010
# 30537  Enhanced Characterness for Text Detection in t...  2017
# ...                                                  ...   ...
# 21790  Towards Faster Rates and Oracle Property for L...  2015
# 22674  Massive Data Clustering in Moderate Dimensions...  2017
# 22342  The Segmented iHMM: A Simple, Efficient Hierar...  2016
# 22929  Extracting low-dimensional dynamics from multi...  2017
# 38555  Image Deblurring and Super-resolution by Adapt...  2010
#
#                                                 keywords
# 11778  [relationships, extensions, clustering, approa...
# 7847   [algorithm, distribution, presented, sequentia...
# 23600  [reconstruction, measurements, importance, eng...
# 21550  [challenging, estimating, dimensional, graphic...
# 30537  [interesting, improving, detection, utilizing,...
# ...                                                  ...
# 21790  [framework, estimation, nonconvex, penalties, ...
# 22674  [dimensional, properties, dimensionality, info...
# 22342  [segmented, hierarchical, efficient, inference...
# 22929  [understanding, population, dimensional, traje...
# 38555  [statistical, technique, representation, succe...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 11778    [relationships, extensions, clustering, approa...
# 7847     [algorithm, distribution, presented, sequentia...
# 23600    [reconstruction, measurements, importance, eng...
# 21550    [challenging, estimating, dimensional, graphic...
# 30537    [interesting, improving, detection, utilizing,...
#                                ...
# 12945    [addresses, distributed, communication, constr...
# 12548    [statistical, protecting, sensitive, informati...
# 913      [recurrent, developed, variation, recurrent, e...
# 411      [multimodal, multilingual, addressing, automat...
# 7705     [dimensional, healthcare, neuroscience, unavoi...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8796 words.
# Out of those 4524 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="2514d714-37d6-4ae8-a287-6723df8a7202" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2514d714-37d6-4ae8-a287-6723df8a7202")) {                    Plotly.newPlot(                        "2514d714-37d6-4ae8-a287-6723df8a7202",                        [{"x":["numerical","expensive","arithmetic","laplacians","eigenvectors","outperforms","relationships","geometric","clustering","approaches","structures","computationally","efficiently","situations","extensions","independent","underlying","observations","generalization","incrementally","presented","algorithm","sequentially","parameterized","theoretically","guarantees","incorporate","performance","distribution","asymptotic","empirically","empirical","semidefinite","stochastic","properties","statistical","incremental","regression","alternatives","specifically","limitations","efficiency","precision","stability","algorithms","degradation","iterative","measurement","procedure","simulated","associated","typically","corrupted","consequently","represented","probability","maximizer","methodology","convergence","richardson","deteriorate","computational","measurements","resolution","relatively","transform","restoration","accordingly","posteriori","importance","introduced","reconstruction","influence","criterion","assumption","engineering","destructive","experiments","shrinkage","simultaneously","estimating","techniques","selection","interpretation","parameter","essentially","microarray","graphical","dependent","undirected","challenging","inference","partially","regularization","replicable","information","procedures","validation","including","estimation","conditions","dimensional","synthetic","competing","improving","comprehensive","combination","detection","comparative","maximally","traditional","interesting","utilizing","evaluation","transparent","parametric","inherently","reduction","performing","similarity","structural","densities","dimensions","demonstrate","neighborhood","introduce","structure","dimension","particular","modifying","dimensionality","consequences","similarities","applications","extracted","distances","framework","classification","individual","classifier","predicted","influential","currently","decisions","explanations","conditional","expectation","variables","extending","dependence","understanding","particularly","exploration","rendering","posterior","deterministic","alternative","maximization","infeasible","mitigation","decreases","favorably","triggering","catastrophic","benchmarks","gracefully","normalized","progression","instantly","increases","abilities","evaluated","historical","motivated","languages","averaging","contained","subjective","collected","modalities","automated","levenshtein","replicated","renormalization","phylogeny","percentage","developed","subjectivity","concerning","considering","geographical","illustrate","differences","furnishes","sufficient","condition","approximation","concisely","axiomatization","application"],"y":[84,66,13,2,5,257,70,77,145,442,139,99,146,44,39,132,107,67,109,15,159,843,25,23,34,59,64,858,212,20,78,158,8,126,173,172,38,117,25,177,72,164,68,42,623,15,86,32,129,68,123,93,18,38,75,160,3,62,111,4,4,288,53,118,70,58,12,30,16,70,119,108,59,49,67,51,2,630,6,107,61,409,162,68,127,27,1,55,85,17,257,208,35,68,2,744,43,50,263,209,120,199,124,28,103,49,156,326,33,11,179,66,45,256,7,40,18,85,94,142,68,13,51,571,28,302,327,67,259,17,47,14,37,418,123,37,535,518,121,148,40,9,68,53,26,104,42,124,34,28,170,71,47,12,44,32,102,39,6,0,20,19,2,10,81,2,28,5,3,55,13,131,25,49,105,18,30,30,74,35,91,2,3,3,3,15,227,4,12,82,7,66,64,2,66,53,110,3,2,257],"type":"bar"},{"x":["numerical","expensive","arithmetic","laplacians","eigenvectors","outperforms"," ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4524,), (4524, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8275

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Scaling</span> <span style='background-color:rgba(255, 0, 0, 0.3913043478260869);'>Submodular</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Maximization</span> <span style=''>via</span> <span style=''>Pruned</span> <span style='background-color:rgba(255, 0, 0, 0.33333333333333337);'>Submodularity</span> <span style=''>Graphs</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>new</span> <span style=''>random</span> <span style=''>pruning</span> <span style=''>method</span> <span style=''>(called</span> <span style='background-color:rgba(255, 0, 0, 0.3913043478260869);'>submodular</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sparsification</span> <span style=''>(SS))</span> <span style=''>to</span> <span style=''>reduce</span> <span style=''>the</span> <span style=''>cost</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3913043478260869);'>submodular</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>maximization</span> <span style=''>The</span> <span style=''>pruning</span> <span style=''>is</span> <span style=''>applied</span> <span style=''>via</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.33333333333333337);'>submodularity</span> <span style=''>graph</span> <span style=''>over</span> <span style=''>the</span> <span style=''>n</span> <span style=''>ground</span> <span style=''>elements</span> <span style=''>where</span> <span style=''>each</span> <span style=''>directed</span> <span style=''>edge</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>associated</span> <span style=''>with</span> <span style=''>a</span> <span style=''>pairwise</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dependency</span> <span style=''>defined</span> <span style=''>by</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3913043478260869);'>submodular</span> <span style=''>function</span> <span style=''>In</span> <span style=''>each</span> <span style=''>step</span> <span style=''>SS</span> <span style=''>prunes</span> <span style=''>a</span> <span style=''>1</span> <span style=''>1sqrtc</span> <span style=''>(for</span> <span style=''>c1)</span> <span style=''>fraction</span> <span style=''>of</span> <span style=''>the</span> <span style=''>nodes</span> <span style=''>using</span> <span style=''>weights</span> <span style=''>on</span> <span style=''>edges</span> <span style=''>computed</span> <span style=''>based</span> <span style=''>on</span> <span style=''>only</span> <span style=''>a</span> <span style=''>small</span> <span style=''>number</span> <span style=''>(O(log</span> <span style=''>n))</span> <span style=''>of</span> <span style=''>randomly</span> <span style=''>sampled</span> <span style=''>nodes</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>requires</span> <span style=''>log</span> <span style=''>sqrtcn</span> <span style=''>steps</span> <span style=''>with</span> <span style=''>a</span> <span style=''>small</span> <span style=''>and</span> <span style=''>highly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parallelizable</span> <span style=''>per</span> <span style=''>step</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computation</span> <span style=''>An</span> <span style=''>accuracy</span> <span style=''>speed</span> <span style=''>tradeoff</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameter</span> <span style=''>c</span> <span style=''>set</span> <span style=''>as</span> <span style=''>c</span> <span style=''>8</span> <span style=''>leads</span> <span style=''>to</span> <span style=''>a</span> <span style=''>fast</span> <span style=''>shrink</span> <span style=''>rate</span> <span style=''>sqrt24</span> <span style=''>and</span> <span style=''>small</span> <span st ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Estimating</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Probability</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Distributions</span> <span style=''>using</span> <span style=''>Dirac</span> <span style=''>Kernels</span> <span style=''>(via</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Rademacher</span> <span style=''>Walsh</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Polynomial</span> <span style=''>Basis</span> <span style=''>Functions)</span> <br/><br/><span style=''>In</span> <span style=''>many</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applications</span> <span style=''>(in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>particular</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>systems</span> <span style=''>such</span> <span style=''>as</span> <span style=''>pattern</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>recognition</span> <span style=''>machine</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>cheminformatics</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>bioinformatics</span> <span style=''>to</span> <span style=''>name</span> <span style=''>but</span> <span style=''>a</span> <span style=''>few)</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>assessment</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>uncertainty</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>essential</span> <span style=''>ie</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>underlying</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probability</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>function</span> <span style=''>More</span> <span style=''>often</span> <span style=''>than</span> <span style=''>not</span> <span style=''>the</span> <span style=''>form</span> <span style=''>of</span> <span style=''>this</span> <span style=''>function</span> <span style=''>is</span> <span style=''>unknown</span> <span style=''>and</span> <span style=''>it</span> <span style=''>becomes</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>necessary</span> <span style=''>to</span> <span style=''>non</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parametrically</span> <span style=''>constructestimate</span> <span style=''>it</span> <span style=''>from</span> <span style=''>a</span> <span style=''>given</span> <span style=''>sample</span> <span style=''>One</span> <span style=''>of</span> <span style=''>the</span> <span style=''>methods</span> <span style=''>of</span> <span style=''>choice</span> <span style=''>to</span> <span style=''>non</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parametrically</span> <span style=''>estimate</span> <span style=''>the</span> <span style=''>unknown</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probability</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>function</span> <span style=''>for</span> <span style=''>a</span> <span style=''>given</span> <span style=''>random</span> <span style=''>variable</span> <span style=''>(defined</span> <span style=''>on</span> <span style=''>binary</span> <span style=''>space)</span> <span style=''>has</span> <span style=''>been</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>expansion</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>function</span> <span style=''>in</span> <span style='background ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.7123287671232876);'>Nonparametric</span> <span style='background-color:rgba(255, 0, 0, 0.5719844357976653);'>Variational</span> <span style=''>Auto</span> <span style=''>encoders</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Hierarchical</span> <span style='background-color:rgba(0, 255, 0, 0.4244604316546763);'>Representation</span> <span style=''>Learning</span> <br/><br/><span style=''>The</span> <span style=''>recently</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>developed</span> <span style='background-color:rgba(255, 0, 0, 0.5719844357976653);'>variational</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>autoencoders</span> <span style=''>(VAEs)</span> <span style=''>have</span> <span style=''>proved</span> <span style=''>to</span> <span style=''>be</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>effective</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>confluence</span> <span style=''>of</span> <span style=''>the</span> <span style=''>rich</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>representational</span> <span style=''>power</span> <span style=''>of</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>with</span> <span style=''>Bayesian</span> <span style=''>methods</span> <span style=''>However</span> <span style=''>most</span> <span style=''>work</span> <span style=''>on</span> <span style=''>VAEs</span> <span style=''>use</span> <span style=''>a</span> <span style=''>rather</span> <span style=''>simple</span> <span style=''>prior</span> <span style=''>over</span> <span style=''>the</span> <span style=''>latent</span> <span style='background-color:rgba(255, 0, 0, 0.3784461152882205);'>variables</span> <span style=''>such</span> <span style=''>as</span> <span style=''>standard</span> <span style=''>normal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribution</span> <span style=''>thereby</span> <span style='background-color:rgba(255, 0, 0, 0.4117647058823529);'>restricting</span> <span style=''>its</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>applications</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>relatively</span> <span style=''>simple</span> <span style='background-color:rgba(0, 255, 0, 0.3333333333333333);'>phenomena</span> <span style=''>In</span> <span style=''>this</span> <span style=''>work</span> <span style=''>we</span> <span style=''>propose</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hierarchical</span> <span style='background-color:rgba(255, 0, 0, 0.7123287671232876);'>nonparametric</span> <span style='background-color:rgba(255, 0, 0, 0.5719844357976653);'>variational</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>autoencoders</span> <span style=''>which</span> <span style=''>combines</span> <span style=''>tree</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structured</span> <span style=''>Bayesian</span> <span style='background-color:rgba(255, 0, 0, 0.7123287671232876);'>nonparametric</span> <span style=''>priors</span> <span style=''>with</span> <span style=''>VAEs</span> <span style=''>to</span> <span style=''>enable</span> <span style=''>infinite</span> <span style='background-color:rgba(255, 0, 0, 0.30666666666666664);'>flexibility</span> <span style=''>of</span> <span style=''>the</span> <span style=''>latent</span> <span style='background-color:rgba(0, 255, 0, 0.4244604316546763);'>representation</span> <span style=''>space</span> <span style=''>Both</span> <span style=''>the</span> <span style=''>neural</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameters</span> <span style=''>and</span> <span style=''>Bayesian</span> <span style=''>priors</span> <span style=''>are</span> <span style=''>learned</span> <span style=''>jointly</span> <span style=''>using</span> <s ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Towards</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Characterizing</span> <span style=''>Markov</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Equivalence</span> <span style=''>Classes</span> <span style=''>for</span> <span style=''>Directed</span> <span style=''>Acyclic</span> <span style=''>Graphs</span> <span style=''>with</span> <span style=''>Latent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Variables</span> <br/><br/><span style=''>It</span> <span style=''>is</span> <span style=''>well</span> <span style=''>known</span> <span style=''>that</span> <span style=''>there</span> <span style=''>may</span> <span style=''>be</span> <span style=''>many</span> <span style=''>causal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>explanations</span> <span style=''>that</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>consistent</span> <span style=''>with</span> <span style=''>a</span> <span style=''>given</span> <span style=''>set</span> <span style=''>of</span> <span style=''>data</span> <span style=''>Recent</span> <span style=''>work</span> <span style=''>has</span> <span style=''>been</span> <span style=''>done</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>represent</span> <span style=''>the</span> <span style=''>common</span> <span style=''>aspects</span> <span style=''>of</span> <span style=''>these</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>explanations</span> <span style=''>into</span> <span style=''>one</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representation</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>address</span> <span style=''>what</span> <span style=''>is</span> <span style=''>less</span> <span style=''>well</span> <span style=''>known</span> <span style=''>how</span> <span style=''>do</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>relationships</span> <span style=''>common</span> <span style=''>to</span> <span style=''>every</span> <span style=''>causal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>explanation</span> <span style=''>among</span> <span style=''>the</span> <span style=''>observed</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>of</span> <span style=''>some</span> <span style=''>DAG</span> <span style=''>process</span> <span style=''>change</span> <span style=''>in</span> <span style=''>the</span> <span style=''>presence</span> <span style=''>of</span> <span style=''>latent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Ancestral</span> <span style=''>graphs</span> <span style=''>provide</span> <span style=''>a</span> <span style=''>class</span> <span style=''>of</span> <span style=''>graphs</span> <span style=''>that</span> <span style=''>can</span> <span style=''>encode</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conditional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>independence</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>relations</span> <span style=''>that</span> <span style=''>arise</span> <span style=''>in</span> <span style=''>DAG</span> <span style=''>models</span> <span style=''>with</span> <span style=''>latent</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>present</span> <span style=''>a</span> <span style=''>set</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>orientation</span> <span style=''>rules</span> <span style=''>that</ ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	evaluation (0.09221902017291066)
# 	segmentation (0.06231988472622478)
# 	processing (0.10554755043227666)
# 	knowledge (0.13652737752161384)
# 	representation (0.14265129682997119)
# 	detection (0.11743515850144093)
# 	information (0.2680115273775216)
# 	different (0.2712536023054755)
# 	convolutional (0.13112391930835735)
# 	recognition (0.13256484149855907)
#
# Some Statistics words are:
# 	stochastic (0.12697628458498023)
# 	distributions (0.125)
# 	variables (0.1358695652173913)
# 	statistical (0.15760869565217392)
# 	theoretical (0.15711462450592886)
# 	estimation (0.18181818181818182)
# 	distribution (0.19120553359683795)
# 	dimensional (0.191699604743083)
# 	inference (0.1976284584980237)
# 	regression (0.18280632411067194)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="f817131d-fbf1-4cc9-afe6-104b04a64a4a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f817131d-fbf1-4cc9-afe6-104b04a64a4a")) {                    Plotly.newPlot(                        "f817131d-fbf1-4cc9-afe6-104b04a64a4a",                        [{"x":["numerical","expensive","arithmetic","laplacians","eigenvectors","outperforms","relationships","geometric","clustering","approaches","structures","computationally","efficiently","situations","extensions","independent","underlying","observations","generalization","incrementally","presented","algorithm","sequentially","parameterized","theoretically","guarantees","incorporate","performance","distribution","asymptotic","empirically","empirical","semidefinite","stochastic","properties","statistical","incremental","regression","alternatives","specifically","limitations","efficiency","precision","stability","algorithms","degradation","iterative","measurement","procedure","simulated","associated","typically","corrupted","consequently","represented","probability","maximizer","methodology","convergence","richardson","deteriorate","computational","measurements","resolution","relatively","transform","restoration","accordingly","posteriori","importance","introduced","reconstruction","influence","criterion","assumption","engineering","destructive","experiments","shrinkage","simultaneously","estimating","techniques","selection","interpretation","parameter","essentially","microarray","graphical","dependent","undirected","challenging","inference","partially","regularization","replicable","information","procedures","validation","including","estimation","conditions","dimensional","synthetic","competing","improving","comprehensive","combination","detection","comparative","maximally","traditional","interesting","utilizing","evaluation","transparent","parametric","inherently","reduction","performing","similarity","structural","densities","dimensions","demonstrate","neighborhood","introduce","structure","dimension","particular","modifying","dimensionality","consequences","similarities","applications","extracted","distances","framework","classification","individual","classifier","predicted","influential","currently","decisions","explanations","conditional","expectation","variables","extending","dependence","understanding","particularly","exploration","rendering","posterior","deterministic","alternative","maximization","infeasible","mitigation","decreases","favorably","triggering","catastrophic","benchmarks","gracefully","normalized","progression","instantly","increases","abilities","evaluated","historical","motivated","languages","averaging","contained","subjective","collected","modalities","automated","levenshtein","replicated","renormalization","phylogeny","percentage","developed","subjectivity","concerning","considering","geographical","illustrate","differences","furnishes","sufficient","condition","approximation","concisely","axiomatization","application","extensively","decomposition","transpose","important","axiomatized","equivalently","necessary","systematic","efficient","decompose","characteristic","representations","represent","operators","estimators","encompasses","optimization","uncertainty","distributionally","rigorously","regularized","transport","distributional","counterfactual","suboptimal","individually","detailing","different","interactions","providing","community","identification","platforms","published","consistently","argumentation","conversation","frameworks","potentially","leveraging","positions","communitys","primitives","modelling","reactions","correlation","correlations","determined","probabilistic","deviations","conditioning","principle","capturing","generally","coin ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	mitigation
# 	detailing
# 	debiasing
# 	reparametrization
# 	reparametrizations
# 	subsamples
# 	inductively
# 	integrative
# 	diagonalization
# 	dependences
# 	nonadaptive
# 	criterions
# 	presupposes
# 	parsimony
# 	penalization
# 	supersparse
# 	sandwiched
# 	discriminators
# 	nutrition
# 	statistic
# Some words which never appear in Statistics papers:
# 	destructive
# 	levenshtein
# 	phylogeny
# 	furnishes
# 	axiomatization
# 	axiomatized
# 	argumentation
# 	conversation
# 	unobtrusive
# 	cryptographic
# 	personalities
# 	consumers
# 	euclidian
# 	neologisms
# 	entangled
# 	binocular
# 	functionality
# 	assistants
# 	radiologists
# 	frustrated

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.097509602279767e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.785
